# %%
import numpy as np
import pandas as pd
from astroquery.gaia import Gaia
from astroquery.simbad import Simbad
import matplotlib.pyplot as plt
from astropy.table import Column, join, Table, vstack, hstack
from astropy.io import ascii
from HMXB_pipeline_class import pipeline
import os

# %%
HMXB_table = ascii.read('HMXB_20241128_.csv',format='csv')

# %%
HMXB_table
# Out:
# <Table length=121>
#      source_id              ra         ... M_companion_upper        Name
#        int64             float64       ...      float64            str23
# ------------------- ------------------ ... ----------------- ------------------
#  168450545792009600  58.84615062234396 ...                --        4U 0352+309
#  184497471323752064  80.64680481184236 ...                --           HD 34921
#  252878401557369088  70.24720739300419 ...                --         BSD 24-491
#  276644757710014976  64.92556123476727 ...                --      XTE J0421+560
#  414196617287885312 18.996040698840275 ...                --     TYC 3681-695-1
#  426558460884582016 14.177450998208093 ...                --            gam Cas
#  427234969757165952  9.290132580203235 ...                --    IGR J00370+6122
#  444752973131169664 53.749629724978455 ...                --           V0332+53
#  465628193526364416  40.91843191991435 ...                -- Swift J0243.6+6124
# ...

# %%
HMXB_table_pd = HMXB_table.to_pandas()

# %%
output = HMXB_table_pd[['Name','l','b','distance','pm_l_poleski','pm_b_poleski','Peculiar Velocity','Mass_compact','M_compact_lower','M_compact_upper','Mass_companion','M_companion_lower','M_companion_upper']]

# %%
output = output.round({'l':2,'b':2,'distance':2,'pm_l_poleski':2,'pm_b_poleski':2,'Peculiar_velocity':1,'Mass_compact':2,'M_compact_lower':2,'M_compact_upper':2,'Mass_companion':2,'M_companion_lower':2,'M_companion_upper':2})

# %%
#above didn't work but this does
output['Peculiar Velocity']=output['Peculiar Velocity'].round(2)

# %%
output2 =
# Out:
#                 Name       l      b  distance  pm_l_poleski  pm_b_poleski  \
# 0        4U 0352+309  163.08 -17.14      0.61          0.31         -2.25
# 1           HD 34921  170.05   0.71      1.39          4.04         -1.18
# 2         BSD 24-491  159.85  -1.27      2.64          0.96         -0.70
# 3      XTE J0421+560  149.18   4.13      4.76          0.03         -0.70
# 4     TYC 3681-695-1  126.08  -3.57      2.95         -2.39         -0.80
# ..               ...     ...    ...       ...           ...           ...
# 116    1ES 1210-64.6  298.89  -2.30      3.78         -5.96         -0.38
# 117       3U 1223-62  300.10  -0.04      3.99         -5.03         -2.52
# 118  IGR J12341-6143  300.87   1.08     71.51         -5.17          0.70
# 119        HD 110432  301.96  -0.20      0.44        -12.77         -3.98
# 120        mu.02 Cru  303.36   5.70      0.12        -28.61         -9.82
#
#      Peculiar Velocity  Mass_compact  M_compact_lower  M_compact_upper  \
# ...

# %%
path  =os.getcwd()
path
# Out:
# '/home/karan/Documents/UvA/Thesis'

# %%
latex_table = output.to_latex()
with open(f"{path}/Tables/test_first.tex", "w") as file:
    file.write(latex_table)
