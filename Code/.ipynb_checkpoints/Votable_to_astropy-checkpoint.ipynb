# %%
import numpy as np
import pandas as pd
from astroquery.gaia import Gaia
from astroquery.simbad import Simbad
import matplotlib.pyplot as plt
from astropy.table import Column, join, Table, vstack, hstack
from astropy.io import ascii
from HMXB_pipeline_class import pipeline
import astropy.coordinates as coords
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.visualization import astropy_mpl_style
import corner
from datetime import datetime
import os
from Galactic_traceback import GalacticTraceback

# %%
from astropy.io.votable import parse

# %%
csv_files = '/home/karan/Documents/UvA/Thesis/DATA/'

# %%
scoob1 = parse('/home/karan/Documents/UvA/Thesis/scoob1.xml')
ankay = parse('/home/karan/Documents/UvA/Thesis/Tables/Ankay_stars')
NGC6231 = parse(csv_files+'NGC6231')
Cepob1 = parse('/home/karan/Documents/UvA/Thesis/Tables/CEPOB1.xml')
Berkely97 = parse('/home/karan/Documents/UvA/Thesis/DATA/Berkley_97.xml')
#CYGOB2 = parse('/home/karan/Documents/UvA/Thesis/DATA/CYGOB2')
RCW38 = parse('/home/karan/Documents/UvA/Thesis/DATA/RCW38')
platais9 = parse(csv_files+'Platais9')
Ngc7380 = parse(csv_files+'NGC7380')
Ngc6871 = parse(csv_files+'NGC6871')

# %%
Simbad.add_votable_fields("parallax")

# %%
options = Simbad.list_votable_fields()

# %%
x = Simbad.query_object('Ass Cep OB 1')

# %%
x
# Out:
# <Table length=1>
#   main_id       ra     dec   coo_err_maj ... plx_err plx_value  matched_id
#                deg     deg       mas     ...   mas      mas
#    object    float64 float64   float32   ... float32  float64     object
# ------------ ------- ------- ----------- ... ------- --------- ------------
# Ass Cep OB 1  337.25    56.6          -- ...      --        -- Ass Cep OB 1

# %%
def make_astropy_table(parsed_name):
    '''chatgpt this shit fuck simbad'''
    resources = parsed_name.resources
    if len(resources) > 0:
        # Access the first resource
        resource = resources[0]
        
        # Retrieve tables from the resource
        tables = resource.tables
        
        # Access the first table (if there's only one)
        if len(tables) > 0:
            table = tables[0]
            
            # Convert to an Astropy Table
            astro_table = table.to_table()
        else:
            print("No tables found in the first resource.")
    else:
        print("No resources found in the VOTable.")

    return astro_table

# %%
from astroquery.simbad import Simbad

def get_gaia_id_from_simbad(object_name):
    '''Query SIMBAD to retrieve the GAIA DR3 ID using query_objectids for a given object name.'''
    simbad = Simbad()

    # Query object identifiers for the object
    result = simbad.query_objectids(object_name)

    if result is not None:
        # Search for the GAIA DR3 ID in the result
        gaia_ids = [obj_id for obj_id in result['id'] if 'Gaia DR3' in obj_id]
        
        if gaia_ids:
            cleaned_gaia_id = gaia_ids[0].replace('Gaia DR3', '').strip()
            return cleaned_gaia_id
            # Return the first GAIA DR3 ID
        else:
            return None
    else:
        return None

# Query for V* V1290 Sco
print(get_gaia_id_from_simbad('V* V1290 Sco'))
# Out:
# 5968081461246595456

# %%
def add_gaia_ids_to_table(table):
    '''Add GAIA DR3 IDs to an Astropy Table.'''
    gaia_ids = []
    
    # Loop through each object in the table and get the GAIA DR3 ID
    for object_name in table['MAIN_ID']:
        gaia_id = get_gaia_id_from_simbad(object_name)
        gaia_ids.append(gaia_id)
    
    # Add a new column to the table for GAIA DR3 IDs
    table['GAIA_DR3'] = gaia_ids
    return table

# %%
# Convert it to an Astropy Table for easy manipulation
scoob1_table = make_astropy_table(scoob1)

# %%
RCW38_table = make_astropy_table(RCW38)
#RCW38_table

# %%
Platais9_table = make_astropy_table(platais9)

# %%
Platais9_table.write(csv_files+'Platais9.ecsv',format='ascii.ecsv',overwrite=True)

# %%
RCW38_table.write('/home/karan/Documents/UvA/Thesis/DATA/RCW_38.ecsv',format='ascii.ecsv',overwrite=True)

# %%
Ngc7380_table = make_astropy_table(Ngc7380)

# %%
Ngc7380_table.write(csv_files+'Ngc7380.ecsv',format='ascii.ecsv',overwrite=True)

# %%
Ngc6871_table = make_astropy_table(Ngc6871)

# %%
Ngc6871_table.write(csv_files+'Ngc6871.ecsv',format='ascii.ecsv',overwrite=True)

# %%
Ngc6231_table = make_astropy_table(NGC6231)
Ngc6231_table
# Out:
# <Table length=4223>
# TYPED_ID MATCHING_ID  ANG_DIST ...     IUE_bibcode     XMM_Obsno    OID4
#                        arcsec  ...
#  object     object    float32  ...        str19          str10     object
# -------- ----------- --------- ... ------------------- --------- ---------
#                      2875.1399 ...                                @2314494
#                      2315.8000 ...                                @2314499
#                      1739.0601 ... 1996IUEML.C......0I            @2314502
#                      1464.1300 ...                                @2314505
#                      1745.0300 ...                                @2314506
#                      1931.8800 ...                                @2315139
#                      1172.5200 ...                                @2315143
#                      1210.3300 ... 1996IUEML.C......0I            @2315144
#                      1658.4399 ...                                @2315145
#      ...         ...       ... ...                 ...       ...       ...
#                      3112.0901 ...                               @24211882
#                      3159.5601 ...                               @24211883
#                      3237.9900 ...                               @24211884
#                      3311.7000 ...                               @24211885
#                      3401.7400 ...                               @24211886
#                      3353.6899 ...                               @24211887
#                      3437.1599 ...                               @24211888
#                      3475.4099 ...                               @24211889
#                      3488.4299 ...                               @24211890

# %%
Ngc6231_table.write(csv_files+'Ngc6231.ecsv',format='ascii.ecsv',overwrite=True)

# %%
scoob1_table
# Out:
# <Table length=1750>
# TYPED_ID MATCHING_ID  ANG_DIST ...     IUE_bibcode     XMM_Obsno    OID4
#                        arcsec  ...
#  object     object    float32  ...        str19          str10     object
# -------- ----------- --------- ... ------------------- --------- ---------
#                      3158.8601 ... 1996IUEML.C......0I            @2315133
#                      3321.6599 ...                                @2315135
#                      2307.5000 ...                                @2315217
#                       222.1700 ...                                @2315596
#                       872.2500 ...                                @2315888
#                       997.0300 ...                                @2316082
#                      4399.2402 ...                                @2317157
#                      3036.1299 ...                                @2317159
#                      3221.4199 ...                                @2317233
#      ...         ...       ... ...                 ...       ...       ...
#                      6405.2100 ...                               @15318589
#                      6945.2002 ...                               @15318590
#                      7260.2002 ...                               @15318591
#                      7468.0400 ...                               @15318592
#                      7520.0098 ...                               @15318593
#                      6401.4102 ...                               @15318594
#                      7965.1699 ...                               @15318596
#                      8060.3398 ...                               @15318597
#                      8028.0698 ...                               @15995143

# %%
ankay_table = make_astropy_table(ankay)

# %%
ankay_table = ankay_table[ankay_table['MAIN_ID'] != 'NAME Sco OB 1']

# %%
HMXB_table = ascii.read('HMXB_20241202_.csv',format='csv')

# %%
star_170037 =HMXB_table[HMXB_table['Name'] == 'HD 153919']

# %%
# sco_ra = scoob1_table['RA_d']
# sco_dec = scoob1_table['DEC_d']

sco_table = scoob1_table['MAIN_ID','RA_d','DEC_d']

# %%
ankay_table = add_gaia_ids_to_table(ankay_table)

# %%
ankay_table
# Out:
# <Table length=20>
# TYPED_ID MATCHING_ID ANG_DIST ... XMM_Obsno    OID4         GAIA_DR3
#                       arcsec  ...
#  object     object   float32  ...   str10     object         object
# -------- ----------- -------- ... ---------- -------- -------------------
#                            -- ...            @2988660 5620657678322625920
#                            -- ...            @3299333 6054569565614460800
#                            -- ...            @2314493 5968004912078306560
#                            -- ...            @2314494 5968081461246595456
#                            -- ...            @2314501 5969594496668629376
#                            -- ...            @2315164 5966501501704611840
#                            -- ...            @2315409 5964986649547042944
#                            -- ...            @2315168 5966510057279631488
#                            -- ...            @2315133 5969564157008128512
#                            -- ... 0109490801 @2315415 5966509885480902656
#                            -- ...            @2317321                None
#                            -- ...            @2328265 5969686958696979712
#                            -- ...            @2315410 5966563486675142912
#                            -- ...            @2315249 5966450786728068736
#                            -- ...            @2328828 5966667734115159040
#                            -- ...            @2328519 5969698194333785088
#                            -- ...            @2328607                None
#                            -- ... 0083280601 @2344505 5976382915813535232
#                            -- ...            @2344378                None
#                            -- ...             @101996 2006888825592397440

# %%
NGC_6231_table = add_gaia_ids_to_table(make_astropy_table(NGC6231))

# %%
NGC_6231_table
# Out:
# <Table length=1>
# TYPED_ID MATCHING_ID ANG_DIST  MAIN_ID  ... XMM_Obsno   OID4   GAIA_DR3
#                       arcsec            ...
#  object     object   float32    object  ...   str10    object   object
# -------- ----------- -------- --------- ... --------- -------- --------
# NGC 6231                   -- NGC  6231 ...           @2317321     None

# %%
cepob1_table = make_astropy_table(Cepob1)

# %%
cepob1_table = add_gaia_ids_to_table(cepob1_table)

# %%
cepob1_table
# Out:
# <Table length=1>
# TYPED_ID MATCHING_ID ANG_DIST   MAIN_ID    ... XMM_Obsno   OID4  GAIA_DR3
#                       arcsec               ...
#  object     object   float32     object    ...   str10    object  object
# -------- ----------- -------- ------------ ... --------- ------- --------
#  CEP OB1                   -- Ass Cep OB 1 ...           @101699     None

# %%
Berkley_table= make_astropy_table(Berkely97)
Berkley_table = Berkley_table["RA_d", 'DEC_d']
Berk97_sky = SkyCoord(ra=Berkley_table['RA_d'],dec=Berkley_table['DEC_d'])
Berk97_gal = Berk97_sky.transform_to('galactic')
Berkley_table['l'] = Berk97_gal.l
Berkley_table['b'] = Berk97_gal.b
Berkley_table
Berkley_table.write('/home/karan/Documents/UvA/Thesis/DATA/Berkley_97.ecsv',format='ascii.ecsv',overwrite=True)

# %%
def make_Gaia_query(table):
    table = table.to_pandas()
    table_dr3 = table['GAIA_DR3'].dropna()
    list_dr3 = table_dr3.tolist()
    str_dr3 = ','.join(map(str,list_dr3))
    query = f"""
    Select 
    source_id,l,b,ra,dec,parallax,parallax_error
FROM gaiadr3.gaia_source
WHERE source_id IN ({str_dr3})"""
    return query
print(make_Gaia_query(ankay_table))
# Out:
#     Select
#     source_id,l,b,ra,dec,parallax,parallax_error
# FROM gaiadr3.gaia_source
# WHERE source_id IN (5620657678322625920,6054569565614460800,5968004912078306560,5968081461246595456,5969594496668629376,5966501501704611840,5964986649547042944,5966510057279631488,5969564157008128512,5966509885480902656,5969686958696979712,5966563486675142912,5966450786728068736,5966667734115159040,5969698194333785088,5976382915813535232,2006888825592397440)

# %%
scoob1_table = add_gaia_ids_to_table(scoob1_table)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 scoob1_table = add_gaia_ids_to_table(scoob1_table)
#
# Cell In[10], line 7, in add_gaia_ids_to_table(table)
#       5 # Loop through each object in the table and get the GAIA DR3 ID
#       6 for object_name in table['MAIN_ID']:
# ----> 7     gaia_id = get_gaia_id_from_simbad(object_name)
#       8     gaia_ids.append(gaia_id)
#      10 # Add a new column to the table for GAIA DR3 IDs
#
# Cell In[9], line 8, in get_gaia_id_from_simbad(object_name)
#       5 simbad = Simbad()
#       7 # Query object identifiers for the object
# ----> 8 result = simbad.query_objectids(object_name)
#      10 if result is not None:
#      11     # Search for the GAIA DR3 ID in the result
#      12     gaia_ids = [obj_id for obj_id in result['id'] if 'Gaia DR3' in obj_id]
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/astropy/utils/decorators.py:603, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     600             msg += f"\n        Use {alternative} instead."
#     601         warnings.warn(msg, warning_type, stacklevel=2)
# --> 603 return function(*args, **kwargs)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/astroquery/simbad/core.py:1026, in SimbadClass.query_objectids(self, object_name, verbose, cache, get_query_payload, criteria)
#    1024 if criteria is not None:
#    1025     query += f" AND {criteria}"
# -> 1026 return self.query_tap(query, get_query_payload=get_query_payload)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/astroquery/simbad/core.py:1341, in SimbadClass.query_tap(self, query, maxrec, get_query_payload, **uploads)
#    1254 def query_tap(self, query: str, *, maxrec=10000, get_query_payload=False, **uploads):
#    1255     """Query SIMBAD TAP service.
#    1256
#    1257     Parameters
#    (...)
#    1339            c
#    1340     """
# -> 1341     if maxrec > self.hardlimit:
#    1342         raise ValueError(f"The maximum number of records cannot exceed {self.hardlimit}.")
#    1343     if query.count("'") % 2:
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/astroquery/simbad/core.py:165, in SimbadClass.hardlimit(self)
#     163 """The maximum number of lines for SIMBAD's output."""
#     164 if self._hardlimit is None:
# --> 165     self._hardlimit = self.tap.hardlimit
#     166 return self._hardlimit
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/pyvo/dal/tap.py:236, in TAPService.hardlimit(self)
#     227 """
#     228 the hard output limit.
#     229
#    (...)
#     233     if the property is not exposed by the service
#     234 """
#     235 try:
# --> 236     return self.get_tap_capability().outputlimit.hard.content
#     237 except AttributeError:
#     238     pass
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/pyvo/dal/tap.py:138, in TAPService.get_tap_capability(self)
#     130 def get_tap_capability(self):
#     131     """
#     132     returns the (first) TAP capability of this service.
#     133
#    (...)
#     136     A `~pyvo.io.vosi.tapregext.TableAccess` instance.
#     137     """
# --> 138     for capa in self.capabilities:
#     139         if isinstance(capa, tr.TableAccess):
#     140             return capa
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/astropy/utils/decorators.py:836, in lazyproperty.__get__(self, obj, owner)
#     834         val = obj_dict.get(self._key, _NotFound)
#     835         if val is _NotFound:
# --> 836             val = self.fget(obj)
#     837             obj_dict[self._key] = val
#     838 return val
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/pyvo/dal/vosi.py:103, in CapabilityMixin.capabilities(self)
#     101 @lazyproperty
#     102 def capabilities(self):
# --> 103     return vosi.parse_capabilities(self._capabilities().read)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/pyvo/utils/decorators.py:9, in stream_decode_content.<locals>.wrapper(*args, **kwargs)
#       7 @wraps(func)
#       8 def wrapper(*args, **kwargs):
# ----> 9     raw = func(*args, **kwargs)
#      10     raw.read = partial(raw.read, decode_content=True)
#      11     return raw
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/pyvo/dal/vosi.py:99, in CapabilityMixin._capabilities(self)
#      93 @stream_decode_content
#      94 def _capabilities(self):
#      95     """
#      96     Returns capabilities as a
#      97     py:class:`~pyvo.io.vosi.availability.Availability` object
#      98     """
# ---> 99     return self._get_endpoint('capabilities')
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/pyvo/dal/vosi.py:40, in EndpointMixin._get_endpoint(self, endpoint)
#      38 for ep_url in ep_urls:
#      39     try:
# ---> 40         response = self._session.get(ep_url, stream=True)
#      41         response.raise_for_status()
#      42         break
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/GAIA_Query/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(make_Gaia_query(scoob1_table))

# %%
print(ankay_query)

# %%
ra = sco_table['RA_d']
dec = sco_table['DEC_d']

ankay_ra = ankay_table['RA_d']
ankay_dec = ankay_table['DEC_d']
#plt.scatter(ra,dec,s=1,color='k',label='sco')
plt.scatter(ankay_ra,ankay_dec,color='xkcd:pink',label='ankay')
plt.legend()
plt.show()
